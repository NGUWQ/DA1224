# %%
import pandas as pd


data=pd.read_excel('c:/daima/dataanalysis/poem/final.xlsx')
data
# Out:
#       姓名   朝代    人气值  人气值排名   作品获赞量  作品获赞量排名  作品数量  作品数量排名      最终分数  最终排名
# 0     李白   唐代  75122      1  183790        1   177       3  4.087250     1
# 1     苏轼   宋代  55146      4  168360        2   343       1  3.739920     2
# 2    李清照   宋代  58130      2   75533        5    61      11  2.734799     3
# 3     杜甫   唐代  45887      5  119588        3   147       5  2.635244     4
# 4     曹操   两汉  55461      3   23830       20     4      45  2.301930     5
# 5     陆游   宋代  24510     12   68386        6   223       2  1.854558     6
# 6    白居易   唐代  26883     10   85035        4   121       7  1.693425     7
# 7   纳兰性德   清代  29985      9   24029       18   136       6  1.679487     8
# 8    陶渊明   魏晋  34906      6   47273       11    24      24  1.610059     9
# 9     岳飞   宋代  31990      8   21044       23     5      44  1.357732    10
# 10    屈原   先秦  32030      7    8558       37    12      34  1.342874    11
# ...
