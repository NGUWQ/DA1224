# %%
#人气前50分布
import pandas as pd
from pyecharts import Bar,Line,Overlap,configure

configure(global_theme='macarons')
data=pd.read_excel('c:/daima/dataanalysis/poem/102.xlsx')
data['score']=data['hot']+data['enjoy']

grouped=data.groupby(['dynasty'])

grouped_pct = grouped['score']
new=grouped_pct.agg(['count'])
new
bar = Bar("50大诗人分布")
attr=['两汉','五代','元代','先秦','南北朝','唐代','宋代','明代','清代','金朝','魏晋']
v1=new['count']
bar.add("数量", attr,v1,is_label_show=True)
bar.render()
'''
final=data.sort_values('score',ascending=False)[0:50]
final
'''
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'macarons': '/nbextensions/echarts-themes-js/macarons'
#         }
#     });
# </script>
#     <div id="20e116c7fc6a45f691ad18cd61dcbb61" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'macarons'], function(echarts) {
#
# var myChart_20e116c7fc6a45f691ad18cd61dcbb61 = echarts.init(document.getElementById('20e116c7fc6a45f691ad18cd61dcbb61'), 'macarons', {renderer: 'canvas'});
#
# var option_20e116c7fc6a45f691ad18cd61dcbb61 = {
#     "title": [
#         {
#             "text": "50\u5927\u8bd7\u4eba\u5206\u5e03",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
# ...
