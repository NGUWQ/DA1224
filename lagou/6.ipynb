# %%
#箱型图(工资与是否大公司的关系)
import os
import pandas as pd
from pyecharts import Bar,Boxplot
os.chdir('C:/爬虫/拉勾网')

data=pd.read_excel('C:/爬虫/拉勾网/数据分析岗位finals.xlsx')
grouped=data.groupby(['Size'])
grouped_pct=grouped['aSalary']
aprice=grouped_pct.agg(['mean','count'])


y1=data['aSalary'][data['Size']==' 少于15人']
y2=data['aSalary'][data['Size']==' 15-50人']
y3=data['aSalary'][data['Size']==' 50-150人']
y4=data['aSalary'][data['Size']==' 150-500人']
y5=data['aSalary'][data['Size']==' 500-2000人']
y6=data['aSalary'][data['Size']==' 2000人以上']
y6
boxplot = Boxplot("工资与公司规模透视")
x_axis = [ '少于15人','15-50人', '50-150人', '150-500人','500-2000人','2000人以上']
y_axis = [
    y1,
    y2,
    y3,
    y4,
    y5,
    y6
]
_yaxis = boxplot.prepare_data(y_axis)       # 转换数据
boxplot.add("月薪(元)", x_axis, _yaxis,xaxis_rotate=30)
boxplot.render()
boxplot
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="7a479e9db4da4bfa97a04f724fa7581e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_7a479e9db4da4bfa97a04f724fa7581e = echarts.init(document.getElementById('7a479e9db4da4bfa97a04f724fa7581e'), 'light', {renderer: 'canvas'});
#
# var option_7a479e9db4da4bfa97a04f724fa7581e = {
#     "title": [
#         {
#             "text": "\u5de5\u8d44\u4e0e\u516c\u53f8\u89c4\u6a21\u900f\u89c6",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2335803,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "\u6708\u85aa(\u5143)",
#             "data": [
#                 [
#                     2500.0,
#                     4500.0,
#                     10500.0,
#                     14375.0,
#                     37500.0
#                 ],
#                 [
#                     3000.0,
#                     8500.0,
#                     15000.0,
#                     22625.0,
#                     40000.0
#                 ],
#                 [
#                     3500.0,
#                     12000.0,
#                     18000.0,
#                     22500.0,
#                     60000.0
#                 ],
#                 [
#                     3000.0,
#                     12500.0,
#                     16500.0,
#                     22500.0,
#                     60000.0
#                 ],
#                 [
#                     4000.0,
#                     15000.0,
#                     19000.0,
#                     22500.0,
#                     60000.0
#                 ],
#                 [
#                     1500.0,
#                     12500.0,
#                     20000.0,
#                     27500.0,
#                     90000.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2335803
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6708\u85aa(\u5143)"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u5c11\u4e8e15\u4eba",
#                 "15-50\u4eba",
#                 "50-150\u4eba",
#                 "150-500\u4eba",
#                 "500-2000\u4eba",
#                 "2000\u4eba\u4ee5\u4e0a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_7a479e9db4da4bfa97a04f724fa7581e.setOption(option_7a479e9db4da4bfa97a04f724fa7581e);
#
#     });
# </script>
