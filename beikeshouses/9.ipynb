# %%
import os
import pandas as pd
from pyecharts import Bar,Boxplot
os.chdir('C:/爬虫/拉勾网')

data=pd.read_excel('C:/爬虫/拉勾网/all.xlsx')
grouped=data.groupby(['经验','Area'])
grouped_pct=grouped['aSalary']
aprice=grouped_pct.agg(['mean','count'])
aprice['mean']=round(aprice['mean'],0)
aprice
# Out:
#                   mean  count
# 经验       Area
# 经验1-3年   光明新区  12500.0      1
#          南山区   14929.0    658
#          坪山新区   7500.0      1
#          宝安区   11909.0    291
#          盐田区   15333.0      6
#          福田区   14336.0    439
#          罗湖区   12120.0    100
#          龙华新区  11986.0    183
#          龙岗区   12303.0    277
# 经验10年以上  南山区   39167.0      9
#          宝安区   65000.0      1
#          福田区   39583.0      6
#          龙华新区  28750.0      2
#          龙岗区   30000.0      2
# 经验1年以下   南山区   10853.0     17
#          宝安区    9188.0     16
#          福田区   14273.0     11
#          罗湖区   11400.0      5
#          龙华新区  12500.0      9
#          龙岗区    7455.0     11
# 经验3-5年   光明新区  15000.0      2
#          南山区   20057.0   1290
#          坪山新区  19000.0      1
#          宝安区   18885.0    383
#          盐田区   16417.0      6
#          福田区   18575.0    747
#          罗湖区   18194.0    129
#          龙华新区  16522.0    186
#          龙岗区   16436.0    219
# 经验5-10年  南山区   25557.0    323
#          宝安区   27407.0    113
#          盐田区   27500.0      3
#          福田区   25838.0    234
#          罗湖区   24910.0     83
#          龙华新区  21289.0     45
#          龙岗区   23401.0     71
# 经验不限     南山区   17273.0    161
#          坪山新区  10500.0      1
#          宝安区   14995.0    100
#          盐田区   31250.0      2
#          福田区   15500.0    124
#          罗湖区   11148.0     27
#          龙华新区  10524.0     63
#          龙岗区    8993.0     67
# 经验应届毕业生  光明新区  12000.0      1
#          南山区    9737.0     57
#          宝安区    9071.0     21
#          盐田区   15625.0      4
#          福田区    7770.0     37
#          罗湖区    7000.0      5
#          龙华新区   8405.0     21
#          龙岗区   10370.0     46
