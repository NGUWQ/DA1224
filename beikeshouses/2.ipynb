# %%
import os
import pandas as pd
from pyecharts import TreeMap,Bar


os.chdir('C:/爬虫/拉勾网')
attr=["Python", "Java", "C++", "C", "C#", "php"]
v1=[20265,18770,19261,16039,15318,15366]
bar = Bar("x 轴和 y 轴交换")
bar.add("", attr, v1,  is_label_show=True)
bar.render()
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="a5ed4806d34b4048a8259cf1527d4fb2" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_a5ed4806d34b4048a8259cf1527d4fb2 = echarts.init(document.getElementById('a5ed4806d34b4048a8259cf1527d4fb2'), 'light', {renderer: 'canvas'});
#
# var option_a5ed4806d34b4048a8259cf1527d4fb2 = {
#     "title": [
#         {
#             "text": "x \u8f74\u548c y \u8f74\u4ea4\u6362",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...
